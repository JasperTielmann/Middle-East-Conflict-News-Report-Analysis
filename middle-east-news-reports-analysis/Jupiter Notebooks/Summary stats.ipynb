# %% [markdown]
# ## Analysis

# %%
import pandas as pd
import matplotlib.pyplot as plt
from wordcloud import WordCloud

cnn1 = pd.read_csv("cnn.csv")
bbc = pd.read_csv("bbc.csv")
fox = pd.read_csv("fox.csv")
text = pd.concat([cnn1["Text"],bbc["Text"], fox["Text"]],ignore_index=True)

# %%
##Grouping

summary_df = {}
list_s = [cnn1, bbc, fox]
index = 0
for cnn in list_s:
    summary_df[index]={"News Site": cnn["Source"][0],"Text lenght": cnn["Text lenght"].mean(), "Gaza": cnn["Gaza"].mean(), "Palestine": cnn["Palestine"].mean(),
                      "Israel": cnn["Israel"].mean(), "Hamas": cnn["Hamas"].mean(), "Netanyahu": cnn["Netanyahu"].mean(),
                      "Terrorism": cnn["Terrorism"].mean(), "Migration": cnn["Migration"].mean(), "Attacks": cnn["Attacks"].mean(),
                       "Hostages": cnn["Hostages"].mean(), "Killed": cnn["Killed"].mean(), "Air Strike": cnn["Air Strike"].mean(),
                      "Biden": cnn["Biden"].mean()}
    index +=1
summary_df = pd.DataFrame.from_dict(summary_df, orient="index")
summary_df
# Out:
#   News Site  Text lenght  Gaza  Palestine  Israel  Hamas  Netanyahu  \
# 0       CNN      6486.53  4.17       0.23   11.97   2.25       0.78
# 1       BBC      5619.04  6.63       0.82   16.95   6.60       0.87
# 2  Fox News     10586.20  8.25       0.74   33.02  17.18       1.90
#
#    Terrorism  Migration  Attacks  Hostages  Killed  Air Strike  Biden
# 0       0.11       0.05     2.26      0.25    1.48        0.03   1.44
# 1       0.15       0.01     3.93      1.54    2.02        0.60   0.88
# 2       1.05       0.07    10.71      2.23    3.18        0.29   4.38

# %%
#summary_df.to_csv('summary_df.csv')

# %% [markdown]
# ## Word Cloud Generator

# %%
text1 = cnn1["Text"]
test = []
for i in range(100):
    test.append(text1[i])

string_list = [str(item) for item in test]
text = "".join(string_list)  

wordcloud = WordCloud(
    background_color='white',
    width=800,
    height=400
).generate(text)


plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
text1 = fox["Text"]
test = []
for i in range(100):
    test.append(text1[i])

string_list = [str(item) for item in test]
text = "".join(string_list)  

wordcloud = WordCloud(
    background_color='white',
    width=800,
    height=400
).generate(text)

plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
text1 = bbc["Text"]
test = []
for i in range(100):
    test.append(text1[i])

string_list = [str(item) for item in test]
text = "".join(string_list)  

wordcloud = WordCloud(
    background_color='white',
    width=800,
    height=400
).generate(text)

plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
dates = pd.concat([cnn1["Date"],bbc["Date"], fox["Date"]],ignore_index=True)
dates.unique()
# Out:
# array(['   11:16 AM EDT, Wed October 25, 2023',
#        '   10:04 AM EDT, Wed October 25, 2023',
#        '   3:11 PM EDT, Tue October 24, 2023',
#        '   3:02 PM EDT, Tue October 24, 2023',
#        '   5:36 PM EDT, Mon October 23, 2023',
#        '   4:42 PM EDT, Mon October 23, 2023',
#        '   4:20 AM EDT, Mon October 23, 2023',
#        '   3:02 AM EDT, Mon October 23, 2023',
#        '   12:39 PM EDT, Sun October 22, 2023',
#        '   7:50 AM EDT, Sat October 21, 2023',
#        '   3:36 PM EDT, Fri October 20, 2023',
#        '   3:50 AM EDT, Thu May 4, 2023',
#        '   12:42 PM EDT, Sat April 29, 2023',
#        '   9:21 PM EDT, Tue April 18, 2023',
#        '   3:47 PM EDT, Mon April 17, 2023',
#        '   8:50 AM EDT, Mon April 17, 2023',
#        '   4:39 AM EDT, Sun April 9, 2023',
#        '   1:53 AM EDT, Sat April 8, 2023',
#        '   12:22 PM EDT, Fri April 7, 2023',
#        '   12:24 PM EDT, Fri March 31, 2023',
#        '   9:34 AM EDT, Fri March 31, 2023',
#        '   8:45 AM EDT, Fri March 24, 2023',
#        '   10:56 AM EDT, Wed March 22, 2023',
#        '   12:21 AM EDT, Wed March 15, 2023',
#        '   11:35 AM EDT, Mon March 13, 2023',
#        '   2:24 AM EST, Sat March 11, 2023',
#        '   6:46 PM EST, Fri March 10, 2023',
#        '   11:54 AM EST, Fri March 10, 2023',
#        '   10:41 AM EST, Wed March 1, 2023',
#        '   12:03 PM EST, Fri February 24, 2023',
#        '   12:40 PM EST, Thu February 23, 2023',
#        '   12:08 AM EST, Thu February 23, 2023',
#        '   6:30 AM EST, Wed February 22, 2023',
#        '   3:03 AM EST, Tue February 21, 2023',
#        '   9:17 AM EST, Wed February 15, 2023',
#        '   11:51 AM EST, Wed February 8, 2023',
#        '   8:06 AM EST, Sat February 4, 2023',
#        '   6:53 AM EST, Mon January 30, 2023',
#        '   9:37 AM EST, Fri January 13, 2023',
#        '   7:10 AM EST, Wed January 4, 2023',
#        '   8:50 AM EST, Mon January 2, 2023', '7 days ago', '3-Oct',
#        '10 hours ago', '1 day ago', '58 minutes ago', '4 hours ago',
#        '2 days ago', '15-Oct', '10-Oct', '25 October 2023, 08:50 BST',
#        '23-Oct-23', '3 days ago', '10-Oct-23', '20-Jul', '28-Feb',
#        '19-May', '6 days ago', '18-Oct', '5 days ago', '17-Oct', '16-Oct',
#        '13-Oct', '12-Oct', '11-Oct', '13-Oct-23', '11-Oct-23', '9-Oct',
#        '4 days ago', '8-Oct', '7-Oct', '28-Sep', '24-Feb', '15-Feb',
#        '21-Sep', '12-Sep', '16 hours ago',
#        '  October 24, 2023 3:24pm EDT', '  October 25, 2023 1:28pm EDT',
#        '  October 24, 2023 6:45pm EDT', '  October 10, 2023 8:18am EDT',
#        '  October 24, 2023 4:00pm EDT', '  October 12, 2023 4:00am EDT',
#        '  October 11, 2023 9:36pm EDT', '  October 8, 2023 4:28pm EDT',
#        '  October 20, 2023 6:46pm EDT', '  August 7, 2023 9:11am EDT',
#        '  October 7, 2023 3:14pm EDT', '  October 9, 2023 11:39pm EDT',
#        '  October 10, 2023 8:02am EDT', '  October 16, 2023 7:47am EDT',
#        '  October 17, 2023 2:00am EDT', '  July 26, 2023 1:52pm EDT',
#        '  August 31, 2023 5:58pm EDT', '  August 7, 2023 11:20am EDT',
#        '  July 2, 2023 2:19pm EDT', '  March 15, 2023 7:23am EDT',
#        '  February 13, 2023 4:21pm EST', '  October 11, 2023 9:16am EDT',
